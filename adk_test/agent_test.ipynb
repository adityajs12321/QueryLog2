# %%
from agent_v2 import main
# Out:
# /Users/adityajs/QueryLog2/query_log_crewai/lib/python3.12/site-packages/pydantic/_internal/_fields.py:198: UserWarning: Field name "config_type" in "SequentialAgent" shadows an attribute in parent "BaseAgent"
#   warnings.warn(

# %%
completed_session = await main()
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# >>> User Query: whats the weather in new york
# ...
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Completed session:
#  [Event(content=Content(
#   parts=[
#     Part(
#       text='whats the weather in new york'
#     ),
#   ],
#   role='user'
# ), grounding_metadata=None, partial=None, turn_complete=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, invocation_id='e-23d6d60a-fb5b-40de-9878-087de3aae72f', author='user', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}), long_running_tool_ids=None, branch=None, id='959456fa-aec8-4f5a-bb3f-4430f149ee80', timestamp=1759305523.473686), Event(content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
# ...

# %%
print([event.content.parts for event in completed_session if event.content.parts[0].function_call == None])
# Out:
# [[Part(
#   text='whats the weather in new york'
# )], [Part(
#   function_response=FunctionResponse(
#     id='adk-2f63e5b9-cf23-460a-9831-fa5582b1b44e',
#     name='get_weather',
#     response={
#       'report': 'The weather in New York is sunny with a temperature of 25 degrees Celsius (77 degrees Fahrenheit).',
#       'status': 'success'
#     }
#   )
# )], [Part(
#   text='The weather in New York is sunny with a temperature of 25 degrees Celsius (77 degrees Fahrenheit).'
# )]]
